# %% [markdown]
# # Informações:
#
# **Nomes Completos** = Ana Júlia Caetano Martins e Davidson Carvalho dos Santos'
# **Matrículas**    = 20222bsi0091 e 20222bsi0431

# %% [markdown]
# ## Dependências

# %%
import gymnasium as gym
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback
from stable_baselines3.common.monitor import Monitor
import os
import imageio
from datetime import datetime

# %%
# Configurações
TRAINING_CONFIGS = [250_000, 500_000, 750_000]  # Timesteps de treinamento
VIDEO_LENGTH = 1000  # Frames por vídeo
MODEL_DIR = "modelos_salvos"
VIDEO_DIR = "videos_agentes"
LOG_DIR = "logs"

# %%
def create_env():
    """Cria e configura o ambiente CarRacing-v3"""
    env = gym.make('CarRacing-v3', render_mode='rgb_array', continuous=True)
    env = Monitor(env)
    return env

# %%
def train_agent(total_timesteps, run_name):
    """
    Treina o agente PPO
    
    Args:
        total_timesteps: Número total de passos de treinamento
        run_name: Nome para salvar o modelo
    """
    print(f"\n{'='*60}")
    print(f"Iniciando treinamento: {run_name}")
    print(f"Timesteps: {total_timesteps:,}")
    print(f"{'='*60}\n")
    
    # Criar ambiente
    env = DummyVecEnv([create_env])
    
    # Configuração do modelo PPO com hiperparâmetros otimizados
    model = PPO(
        "CnnPolicy",  # Política CNN para processar imagens
        env,
        learning_rate=3e-4,  # Taxa de aprendizado
        n_steps=512,  # Passos por atualização
        batch_size=64,  # Tamanho do batch
        n_epochs=10,  # Épocas de otimização
        gamma=0.99,  # Fator de desconto
        gae_lambda=0.95,  # GAE lambda
        clip_range=0.2,  # Clip range do PPO
        ent_coef=0.01,  # Coeficiente de entropia
        vf_coef=0.5,  # Coeficiente da função de valor
        max_grad_norm=0.5,  # Normalização do gradiente
        verbose=1,
        tensorboard_log=f"{LOG_DIR}/{run_name}"
    )
    
    # Callbacks para salvar checkpoints
    checkpoint_callback = CheckpointCallback(
        save_freq=50_000,
        save_path=f"{MODEL_DIR}/{run_name}_checkpoints",
        name_prefix="ppo_carracing"
    )
    
    # Treinar o modelo
    start_time = datetime.now()
    model.learn(
        total_timesteps=total_timesteps,
        callback=checkpoint_callback,
        progress_bar=True
    )
    end_time = datetime.now()
    
    # Salvar modelo final
    model_path = f"{MODEL_DIR}/ppo_carracing_{run_name}.zip"
    model.save(model_path)
    
    training_time = (end_time - start_time).total_seconds() / 60
    print(f"\n✓ Treinamento concluído em {training_time:.2f} minutos")
    print(f"✓ Modelo salvo em: {model_path}\n")
    
    env.close()
    return model_path

# %%
def evaluate_agent(model_path, num_episodes=5):
    """
    Avalia o agente treinado
    
    Args:
        model_path: Caminho do modelo salvo
        num_episodes: Número de episódios para avaliação
    
    Returns:
        Lista de recompensas totais por episódio
    """
    print(f"Avaliando modelo: {model_path}")
    
    env = gym.make('CarRacing-v3', render_mode='rgb_array', continuous=True)
    model = PPO.load(model_path)
    
    episode_rewards = []
    
    for episode in range(num_episodes):
        obs, info = env.reset()
        total_reward = 0
        done = False
        truncated = False
        steps = 0
        
        while not (done or truncated):
            action, _states = model.predict(obs, deterministic=True)
            obs, reward, done, truncated, info = env.step(action)
            total_reward += reward
            steps += 1
        
        episode_rewards.append(total_reward)
        print(f"  Episódio {episode+1}: Recompensa = {total_reward:.2f}, Passos = {steps}")
    
    env.close()
    
    avg_reward = np.mean(episode_rewards)
    std_reward = np.std(episode_rewards)
    print(f"\n✓ Recompensa Média: {avg_reward:.2f} ± {std_reward:.2f}\n")
    
    return episode_rewards

# %%
def generate_video(model_path, video_name, max_steps=1000):
    """
    Gera vídeo do agente em ação
    
    Args:
        model_path: Caminho do modelo salvo
        video_name: Nome do arquivo de vídeo
        max_steps: Máximo de passos a gravar
    """
    print(f"Gerando vídeo: {video_name}")
    
    env = gym.make('CarRacing-v3', render_mode='rgb_array', continuous=True)
    model = PPO.load(model_path)
    
    frames = []
    obs, info = env.reset()
    total_reward = 0
    
    for step in range(max_steps):
        # Renderizar frame
        frame = env.render()
        frames.append(frame)
        
        # Ação do agente
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, done, truncated, info = env.step(action)
        total_reward += reward
        
        if done or truncated:
            break
    
    env.close()
    
    # Salvar vídeo
    video_path = f"{VIDEO_DIR}/{video_name}"
    imageio.mimsave(video_path, frames, fps=30)
    
    print(f"✓ Vídeo salvo: {video_path}")
    print(f"  Recompensa total: {total_reward:.2f}")
    print(f"  Frames gravados: {len(frames)}\n")
    
    return video_path, total_reward

# %%
def main():
    """Função principal para executar todo o pipeline"""
    print("\n" + "="*60)
    print("TRABALHO 3 - APRENDIZADO POR REFORÇO")
    print("Ambiente: CarRacing-v3")
    print("Algoritmo: PPO (Proximal Policy Optimization)")
    print("="*60 + "\n")
    
    results = {}
    
    # Loop através das configurações de treinamento
    for timesteps in TRAINING_CONFIGS:
        run_name = f"{timesteps//1000}K"
        
        # 1. Treinar o agente
        model_path = train_agent(timesteps, run_name)
        
        # 2. Avaliar o agente
        rewards = evaluate_agent(model_path, num_episodes=5)
        
        # 3. Gerar vídeo
        video_path, video_reward = generate_video(
            model_path, 
            f"carracing_{run_name}.mp4",
            max_steps=1000
        )
        
        # Armazenar resultados
        results[run_name] = {
            'model_path': model_path,
            'video_path': video_path,
            'eval_rewards': rewards,
            'video_reward': video_reward,
            'avg_reward': np.mean(rewards),
            'std_reward': np.std(rewards)
        }
        
        print(f"{'='*60}\n")
    
    # Resumo final
    print("\n" + "="*60)
    print("RESUMO DOS RESULTADOS")
    print("="*60)
    
    for config, data in results.items():
        print(f"\n{config} passos:")
        print(f"  Recompensa média: {data['avg_reward']:.2f} ± {data['std_reward']:.2f}")
        print(f"  Modelo: {data['model_path']}")
        print(f"  Vídeo: {data['video_path']}")
    
    print("\n" + "="*60)
    print("✓ TREINAMENTO COMPLETO!")
    print("="*60 + "\n")
    
    return results

# %%
if __name__ == "__main__":
    # Verificar se o ambiente está disponível
    try:
        env = gym.make('CarRacing-v3')
        env.close()
        print("✓ Ambiente CarRacing-v3 disponível\n")
    except Exception as e:
        print(f"✗ Erro ao carregar ambiente: {e}")
        print("Instale as dependências: pip install gymnasium[box2d]")
        exit(1)
    
    # Executar pipeline completo
    results = main()
# Out:
# /home/davidson/trabalho3_IA/.venv/lib/python3.12/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# ✓ Ambiente CarRacing-v3 disponível
#
#
# ============================================================
# TRABALHO 3 - APRENDIZADO POR REFORÇO
# Ambiente: CarRacing-v3
# Algoritmo: PPO (Proximal Policy Optimization)
# ============================================================
#
#
# ============================================================
# Iniciando treinamento: 250K
# Timesteps: 250,000
# ============================================================
#
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to logs/250K/PPO_1
# /home/davidson/trabalho3_IA/.venv/lib/python3.12/site-packages/rich/live.py:256: UserWarning: install "ipywidgets"
# for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# ----------------------------
# | time/              |     |
# |    fps             | 159 |
# |    iterations      | 1   |
# |    time_elapsed    | 3   |
# |    total_timesteps | 512 |
# ----------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -47.6        |
# | time/                   |              |
# |    fps                  | 150          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 0.0065536965 |
# |    clip_fraction        | 0.04         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.0194      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.503        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00524     |
# |    std                  | 0.999        |
# |    value_loss           | 1.06         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -47.6      |
# | time/                   |            |
# |    fps                  | 150        |
# |    iterations           | 3          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 1536       |
# | train/                  |            |
# |    approx_kl            | 0.00807658 |
# |    clip_fraction        | 0.108      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.25      |
# |    explained_variance   | 0.0576     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0705     |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00816   |
# |    std                  | 0.995      |
# |    value_loss           | 0.592      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -47.8       |
# | time/                   |             |
# |    fps                  | 149         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.012422803 |
# |    clip_fraction        | 0.0934      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.124       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.153       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00814    |
# |    std                  | 0.997       |
# |    value_loss           | 0.631       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -47.8       |
# | time/                   |             |
# |    fps                  | 149         |
# |    iterations           | 5           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.008302573 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | -0.0512     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.107       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00805    |
# |    std                  | 1           |
# |    value_loss           | 0.484       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -45.3        |
# | time/                   |              |
# |    fps                  | 149          |
# |    iterations           | 6            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0077080424 |
# |    clip_fraction        | 0.127        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.0783       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.183        |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00438     |
# |    std                  | 0.999        |
# |    value_loss           | 0.694        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -45.3       |
# | time/                   |             |
# |    fps                  | 149         |
# |    iterations           | 7           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 3584        |
# | train/                  |             |
# |    approx_kl            | 0.012644447 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | -0.0528     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0342     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 1           |
# |    value_loss           | 0.311       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -50.2        |
# | time/                   |              |
# |    fps                  | 148          |
# |    iterations           | 8            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0076965545 |
# |    clip_fraction        | 0.118        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.0437      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.14         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0101      |
# |    std                  | 0.999        |
# |    value_loss           | 0.532        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -50.2       |
# | time/                   |             |
# |    fps                  | 149         |
# |    iterations           | 9           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 4608        |
# | train/                  |             |
# |    approx_kl            | 0.015085509 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.386       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0236     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.018      |
# |    std                  | 0.998       |
# |    value_loss           | 0.191       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -53.5      |
# | time/                   |            |
# |    fps                  | 149        |
# |    iterations           | 10         |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 5120       |
# | train/                  |            |
# |    approx_kl            | 0.01377205 |
# |    clip_fraction        | 0.162      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.25      |
# |    explained_variance   | 0.561      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.106      |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0172    |
# |    std                  | 0.995      |
# |    value_loss           | 0.344      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -53.5      |
# | time/                   |            |
# |    fps                  | 149        |
# |    iterations           | 11         |
# |    time_elapsed         | 37         |
# |    total_timesteps      | 5632       |
# | train/                  |            |
# |    approx_kl            | 0.01185099 |
# |    clip_fraction        | 0.126      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.25      |
# |    explained_variance   | 0.879      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0326     |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0119    |
# |    std                  | 0.999      |
# |    value_loss           | 0.232      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -55.7        |
# | time/                   |              |
# |    fps                  | 149          |
# |    iterations           | 12           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0138396835 |
# |    clip_fraction        | 0.166        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.833        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0317      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | 0.000131     |
# |    std                  | 1            |
# |    value_loss           | 0.26         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -55.7      |
# | time/                   |            |
# |    fps                  | 149        |
# |    iterations           | 13         |
# |    time_elapsed         | 44         |
# |    total_timesteps      | 6656       |
# | train/                  |            |
# |    approx_kl            | 0.01045897 |
# |    clip_fraction        | 0.126      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.25      |
# |    explained_variance   | 0.865      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0167    |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0141    |
# |    std                  | 0.998      |
# |    value_loss           | 0.257      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -57.6       |
# | time/                   |             |
# |    fps                  | 150         |
# |    iterations           | 14          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.014764503 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.018      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0166     |
# |    std                  | 0.998       |
# |    value_loss           | 0.134       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -57.6       |
# | time/                   |             |
# |    fps                  | 150         |
# |    iterations           | 15          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 7680        |
# | train/                  |             |
# |    approx_kl            | 0.008456784 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0458      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00392    |
# |    std                  | 0.995       |
# |    value_loss           | 0.407       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -53.4       |
# | time/                   |             |
# |    fps                  | 150         |
# |    iterations           | 16          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010950841 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.864       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.18        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.019      |
# |    std                  | 0.989       |
# |    value_loss           | 0.609       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -53.4       |
# | time/                   |             |
# |    fps                  | 150         |
# |    iterations           | 17          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 8704        |
# | train/                  |             |
# |    approx_kl            | 0.009943914 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 0.76        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00836     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00945    |
# |    std                  | 0.986       |
# |    value_loss           | 0.437       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -49         |
# | time/                   |             |
# |    fps                  | 150         |
# |    iterations           | 18          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.013795574 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00919     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0204     |
# |    std                  | 0.982       |
# |    value_loss           | 0.43        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -49         |
# | time/                   |             |
# |    fps                  | 149         |
# |    iterations           | 19          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 9728        |
# | train/                  |             |
# |    approx_kl            | 0.017046625 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 0.761       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0216      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0184     |
# |    std                  | 0.981       |
# |    value_loss           | 0.516       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -45.9       |
# | time/                   |             |
# |    fps                  | 149         |
# |    iterations           | 20          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011783668 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.19       |
# |    explained_variance   | 0.868       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0189     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0217     |
# |    std                  | 0.977       |
# |    value_loss           | 0.346       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -45.9       |
# | time/                   |             |
# |    fps                  | 149         |
# |    iterations           | 21          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 10752       |
# | train/                  |             |
# |    approx_kl            | 0.014894998 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.844       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0565      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0244     |
# |    std                  | 0.976       |
# |    value_loss           | 1.34        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -31.5       |
# | time/                   |             |
# |    fps                  | 149         |
# |    iterations           | 22          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.026902562 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.802       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.299       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00942    |
# |    std                  | 0.973       |
# |    value_loss           | 1.85        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -31.5       |
# | time/                   |             |
# |    fps                  | 149         |
# |    iterations           | 23          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 11776       |
# | train/                  |             |
# |    approx_kl            | 0.019331735 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.516       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.832       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0108     |
# |    std                  | 0.971       |
# |    value_loss           | 1.77        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -23.7       |
# | time/                   |             |
# |    fps                  | 149         |
# |    iterations           | 24          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011829766 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.854       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.366       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 0.969       |
# |    value_loss           | 1.22        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -23.7       |
# | time/                   |             |
# |    fps                  | 149         |
# |    iterations           | 25          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.011385161 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.744       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.563       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.016      |
# |    std                  | 0.968       |
# |    value_loss           | 1.98        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -14.5       |
# | time/                   |             |
# |    fps                  | 149         |
# |    iterations           | 26          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.011263376 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.193       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.97        |
# |    value_loss           | 1.18        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -14.5       |
# | time/                   |             |
# |    fps                  | 149         |
# |    iterations           | 27          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 13824       |
# | train/                  |             |
# |    approx_kl            | 0.015718833 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.646       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.457       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.969       |
# |    value_loss           | 2.14        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.75       |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 28          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.020780368 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.202       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.659       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 0.968       |
# |    value_loss           | 2.17        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.75       |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 29          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 14848       |
# | train/                  |             |
# |    approx_kl            | 0.022713954 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.727       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0382      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0174     |
# |    std                  | 0.966       |
# |    value_loss           | 0.993       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.61       |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 30          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.012007759 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.856       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0683      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00334    |
# |    std                  | 0.966       |
# |    value_loss           | 0.731       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -6.61      |
# | time/                   |            |
# |    fps                  | 148        |
# |    iterations           | 31         |
# |    time_elapsed         | 106        |
# |    total_timesteps      | 15872      |
# | train/                  |            |
# |    approx_kl            | 0.00827373 |
# |    clip_fraction        | 0.182      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.15      |
# |    explained_variance   | 0.657      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.286      |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.00844   |
# |    std                  | 0.966      |
# |    value_loss           | 1.61       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 3.29        |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 32          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.015674233 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.229       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.00149     |
# |    std                  | 0.965       |
# |    value_loss           | 1.94        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 3.29        |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 33          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 16896       |
# | train/                  |             |
# |    approx_kl            | 0.024862472 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.775       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00837    |
# |    std                  | 0.962       |
# |    value_loss           | 4.23        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 11.9       |
# | time/                   |            |
# |    fps                  | 148        |
# |    iterations           | 34         |
# |    time_elapsed         | 117        |
# |    total_timesteps      | 17408      |
# | train/                  |            |
# |    approx_kl            | 0.03789018 |
# |    clip_fraction        | 0.323      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.14      |
# |    explained_variance   | 0.338      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.575      |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.00483   |
# |    std                  | 0.962      |
# |    value_loss           | 8.47       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 11.9       |
# | time/                   |            |
# |    fps                  | 148        |
# |    iterations           | 35         |
# |    time_elapsed         | 120        |
# |    total_timesteps      | 17920      |
# | train/                  |            |
# |    approx_kl            | 0.06177602 |
# |    clip_fraction        | 0.301      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.14      |
# |    explained_variance   | 0.838      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.091      |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0232    |
# |    std                  | 0.962      |
# |    value_loss           | 2          |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 15.1        |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 36          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.036021926 |
# |    clip_fraction        | 0.283       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.881       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.241       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00818    |
# |    std                  | 0.964       |
# |    value_loss           | 2.34        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 15.1        |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 37          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 18944       |
# | train/                  |             |
# |    approx_kl            | 0.034246452 |
# |    clip_fraction        | 0.362       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.792       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.116       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.019      |
# |    std                  | 0.964       |
# |    value_loss           | 1.87        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 13.3       |
# | time/                   |            |
# |    fps                  | 148        |
# |    iterations           | 38         |
# |    time_elapsed         | 130        |
# |    total_timesteps      | 19456      |
# | train/                  |            |
# |    approx_kl            | 0.08039016 |
# |    clip_fraction        | 0.226      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.15      |
# |    explained_variance   | 0.982      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0534    |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.00576   |
# |    std                  | 0.966      |
# |    value_loss           | 0.131      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 13.3      |
# | time/                   |           |
# |    fps                  | 148       |
# |    iterations           | 39        |
# |    time_elapsed         | 134       |
# |    total_timesteps      | 19968     |
# | train/                  |           |
# |    approx_kl            | 0.0204813 |
# |    clip_fraction        | 0.327     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.15     |
# |    explained_variance   | 0.683     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.596     |
# |    n_updates            | 380       |
# |    policy_gradient_loss | 0.00374   |
# |    std                  | 0.968     |
# |    value_loss           | 4.48      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 15.9        |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 40          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.011967858 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.109       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 0.968       |
# |    value_loss           | 1.19        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 15.9        |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 41          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 20992       |
# | train/                  |             |
# |    approx_kl            | 0.017620273 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.829       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.469       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0171     |
# |    std                  | 0.968       |
# |    value_loss           | 2.16        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 19.9        |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 42          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.020457106 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.876       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.226       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.968       |
# |    value_loss           | 2.91        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 22.1        |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 43          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 22016       |
# | train/                  |             |
# |    approx_kl            | 0.031115437 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0982      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.026      |
# |    std                  | 0.966       |
# |    value_loss           | 1.24        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 22.1        |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 44          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.025086192 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.321       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 0.967       |
# |    value_loss           | 2.59        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 24.2        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 45          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 23040       |
# | train/                  |             |
# |    approx_kl            | 0.021658588 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.782       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.583       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0179     |
# |    std                  | 0.966       |
# |    value_loss           | 3.9         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 24.2        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 46          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.025701482 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0585      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0218     |
# |    std                  | 0.967       |
# |    value_loss           | 1.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 25.6        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 47          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 24064       |
# | train/                  |             |
# |    approx_kl            | 0.026658408 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.56        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00715     |
# |    std                  | 0.967       |
# |    value_loss           | 3.73        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 25.6        |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 48          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.018482633 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0509      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0171     |
# |    std                  | 0.968       |
# |    value_loss           | 0.892       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 26.8         |
# | time/                   |              |
# |    fps                  | 148          |
# |    iterations           | 49           |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 25088        |
# | train/                  |              |
# |    approx_kl            | 0.0152756665 |
# |    clip_fraction        | 0.225        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.15        |
# |    explained_variance   | 0.93         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.3          |
# |    n_updates            | 480          |
# |    policy_gradient_loss | 0.00873      |
# |    std                  | 0.965        |
# |    value_loss           | 1.58         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 26.8        |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 50          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.021344792 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.863       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0218     |
# |    std                  | 0.964       |
# |    value_loss           | 3.44        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 26          |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 51          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 26112       |
# | train/                  |             |
# |    approx_kl            | 0.031723112 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0555      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.966       |
# |    value_loss           | 1.12        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 26          |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 52          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.026164914 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# ...
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.014878791 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.96       |
# |    explained_variance   | 0.653       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.266       |
# |    n_updates            | 1230        |
# |    policy_gradient_loss | -0.00415    |
# |    std                  | 0.919       |
# |    value_loss           | 1.45        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 990         |
# |    ep_rew_mean          | 135         |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 125         |
# |    time_elapsed         | 431         |
# |    total_timesteps      | 64000       |
# | train/                  |             |
# |    approx_kl            | 0.023688354 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.97       |
# |    explained_variance   | 0.885       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0497      |
# |    n_updates            | 1240        |
# |    policy_gradient_loss | -0.0196     |
# |    std                  | 0.92        |
# |    value_loss           | 0.508       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 990         |
# |    ep_rew_mean          | 134         |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 126         |
# |    time_elapsed         | 434         |
# |    total_timesteps      | 64512       |
# | train/                  |             |
# |    approx_kl            | 0.021837384 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.97       |
# |    explained_variance   | 0.22        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.43        |
# |    n_updates            | 1250        |
# |    policy_gradient_loss | -0.0122     |
# |    std                  | 0.919       |
# |    value_loss           | 1.17        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 990         |
# |    ep_rew_mean          | 134         |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 127         |
# |    time_elapsed         | 438         |
# |    total_timesteps      | 65024       |
# | train/                  |             |
# |    approx_kl            | 0.020467706 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.96       |
# |    explained_variance   | 0.809       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.152       |
# |    n_updates            | 1260        |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.916       |
# |    value_loss           | 1.23        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 990         |
# |    ep_rew_mean          | 133         |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 128         |
# |    time_elapsed         | 441         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.018949257 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.96       |
# |    explained_variance   | 0.454       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.553       |
# |    n_updates            | 1270        |
# |    policy_gradient_loss | -0.0064     |
# |    std                  | 0.916       |
# |    value_loss           | 1.89        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 990         |
# |    ep_rew_mean          | 133         |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 129         |
# |    time_elapsed         | 445         |
# |    total_timesteps      | 66048       |
# | train/                  |             |
# |    approx_kl            | 0.025225287 |
# |    clip_fraction        | 0.352       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.96       |
# |    explained_variance   | 0.76        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.16        |
# |    n_updates            | 1280        |
# |    policy_gradient_loss | 0.0121      |
# |    std                  | 0.915       |
# |    value_loss           | 2.84        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 990         |
# |    ep_rew_mean          | 134         |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 130         |
# |    time_elapsed         | 448         |
# |    total_timesteps      | 66560       |
# | train/                  |             |
# |    approx_kl            | 0.019966917 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.95       |
# |    explained_variance   | 0.401       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.477       |
# |    n_updates            | 1290        |
# |    policy_gradient_loss | 0.00588     |
# |    std                  | 0.915       |
# |    value_loss           | 2.39        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 990         |
# |    ep_rew_mean          | 134         |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 131         |
# |    time_elapsed         | 452         |
# |    total_timesteps      | 67072       |
# | train/                  |             |
# |    approx_kl            | 0.019140895 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.95       |
# |    explained_variance   | 0.868       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.261       |
# |    n_updates            | 1300        |
# |    policy_gradient_loss | -0.0185     |
# |    std                  | 0.916       |
# |    value_loss           | 2.02        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 990         |
# |    ep_rew_mean          | 137         |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 132         |
# |    time_elapsed         | 455         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.014919874 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.95       |
# |    explained_variance   | 0.227       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.689       |
# |    n_updates            | 1310        |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.914       |
# |    value_loss           | 4.67        |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 13
#      10     exit(1)
#      12 # Executar pipeline completo
# ---> 13 results = main()
#
# Cell In[9], line 16, in main()
#      13 run_name = f"{timesteps//1000}K"
#      15 # 1. Treinar o agente
# ---> 16 model_path = train_agent(timesteps, run_name)
#      18 # 2. Avaliar o agente
#      19 rewards = evaluate_agent(model_path, num_episodes=5)
#
# Cell In[6], line 44, in train_agent(total_timesteps, run_name)
#      42 # Treinar o modelo
#      43 start_time = datetime.now()
# ---> 44 model.learn(
#      45     total_timesteps=total_timesteps,
#      46     callback=checkpoint_callback,
#      47     progress_bar=True
#      48 )
#      49 end_time = datetime.now()
#      51 # Salvar modelo final
#
# File ~/trabalho3_IA/.venv/lib/python3.12/site-packages/stable_baselines3/ppo/ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)    309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File ~/trabalho3_IA/.venv/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:324, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     321 assert self.env is not None
#     323 while self.num_timesteps < total_timesteps:
# --> 324     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     326     if not continue_training:
#     327         break
#
# File ~/trabalho3_IA/.venv/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:218, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     213     else:
#     214         # Otherwise, clip the actions to avoid out of bound error
#     215         # as we are sampling from an unbounded Gaussian distribution
#     216         clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 218 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     220 self.num_timesteps += env.num_envs
#     222 # Give access to local variables
#
# File ~/trabalho3_IA/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:222, in VecEnv.step(self, actions)
#     215 """
#     216 Step the environments with the given action
#     217
#     218 :param actions: the action
#     219 :return: observation, reward, done, information
#     220 """
#     221 self.step_async(actions)
# --> 222 return self.step_wait()
#
# File ~/trabalho3_IA/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/vec_transpose.py:97, in VecTransposeImage.step_wait(self)
#      96 def step_wait(self) -> VecEnvStepReturn:
# ---> 97     observations, rewards, dones, infos = self.venv.step_wait()
#      99     # Transpose the terminal observations
#     100     for idx, done in enumerate(dones):
#
# File ~/trabalho3_IA/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:59, in DummyVecEnv.step_wait(self)
#      56 def step_wait(self) -> VecEnvStepReturn:
#      57     # Avoid circular imports
#      58     for env_idx in range(self.num_envs):
# ---> 59         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(  # type: ignore[assignment]
#      60             self.actions[env_idx]
#      61         )
#      62         # convert to SB3 VecEnv api
#      63         self.buf_dones[env_idx] = terminated or truncated
#
# File ~/trabalho3_IA/.venv/lib/python3.12/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File ~/trabalho3_IA/.venv/lib/python3.12/site-packages/gymnasium/wrappers/common.py:125, in TimeLimit.step(self, action)
#     112 def step(
#     113     self, action: ActType
#     114 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     115     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#     116
#     117     Args:
#    (...)    123
#     124     """
# --> 125     observation, reward, terminated, truncated, info = self.env.step(action)
#     126     self._elapsed_steps += 1
#     128     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/trabalho3_IA/.venv/lib/python3.12/site-packages/gymnasium/wrappers/common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File ~/trabalho3_IA/.venv/lib/python3.12/site-packages/gymnasium/core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File ~/trabalho3_IA/.venv/lib/python3.12/site-packages/gymnasium/wrappers/common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File ~/trabalho3_IA/.venv/lib/python3.12/site-packages/gymnasium/envs/box2d/car_racing.py:562, in CarRacing.step(self, action)
#     559 self.world.Step(1.0 / FPS, 6 * 30, 2 * 30)
#     560 self.t += 1.0 / FPS
# --> 562 self.state = self._render("state_pixels")
#     564 step_reward = 0
#     565 terminated = False
#
# File ~/trabalho3_IA/.venv/lib/python3.12/site-packages/gymnasium/envs/box2d/car_racing.py:627, in CarRacing._render(self, mode)
#     624 trans = pygame.math.Vector2((scroll_x, scroll_y)).rotate_rad(angle)
#     625 trans = (WINDOW_W / 2 + trans[0], WINDOW_H / 4 + trans[1])
# --> 627 self._render_road(zoom, trans, angle)
#     628 self.car.draw(
#     629     self.surf,
#     630     zoom,
#    (...)    633     mode not in ["state_pixels_list", "state_pixels"],
#     634 )
#     636 self.surf = pygame.transform.flip(self.surf, False, True)
#
# File ~/trabalho3_IA/.venv/lib/python3.12/site-packages/gymnasium/envs/box2d/car_racing.py:697, in CarRacing._render_road(self, zoom, translation, angle)
#     695 poly = [(p[0], p[1]) for p in poly]
#     696 color = [int(c) for c in color]
# --> 697 self._draw_colored_polygon(self.surf, poly, color, zoom, translation, angle)
#
# File ~/trabalho3_IA/.venv/lib/python3.12/site-packages/gymnasium/envs/box2d/car_racing.py:770, in CarRacing._draw_colored_polygon(self, surface, poly, color, zoom, translation, angle, clip)
#     767 def _draw_colored_polygon(
#     768     self, surface, poly, color, zoom, translation, angle, clip=True
#     769 ):
# --> 770     poly = [pygame.math.Vector2(c).rotate_rad(angle) for c in poly]
#     771     poly = [
#     772         (c[0] * zoom + translation[0], c[1] * zoom + translation[1]) for c in poly
#     773     ]
#     774     # This checks if the polygon is out of bounds of the screen, and we skip drawing if so.
#     775     # Instead of calculating exactly if the polygon and screen overlap,
#     776     # we simply check if the polygon is in a larger bounding box whose dimension
#     777     # is greater than the screen by MAX_SHAPE_DIM, which is the maximum
#     778     # diagonal length of an environment object
#
# KeyboardInterrupt:
# Output()
